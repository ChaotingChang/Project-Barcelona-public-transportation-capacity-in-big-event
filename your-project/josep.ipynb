# %% [markdown]
# # Database connection and queries

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
driver = 'mysql+pymysql:'
user = 'root'
password = '74463IL478obmuJ459'
ip = 'localhost'
database = 'virdishc_Ironhack'

'''
driver = 'mysql+pymysql:'
user = 'virdishc_12345'
password = '12345'
ip = 'az1-ss5.a2hosting.com'
database = 'virdishc_Ironhack'
'''
# Out:
# "\ndriver = 'mysql+pymysql:'\nuser = 'virdishc_12345'\npassword = '12345'\nip = 'az1-ss5.a2hosting.com'\ndatabase = 'virdishc_Ironhack'\n"

# %%
connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
    
engine = create_engine(connection_string)

# %%
query01 = "SELECT * FROM virdishc_Ironhack.00_P2_agency;"
query02 = "SELECT * FROM virdishc_Ironhack.00_P2_calendar;"
query03 = "SELECT * FROM virdishc_Ironhack.00_P2_calendar_dates;"
query04 = "SELECT * FROM virdishc_Ironhack.00_P2_estacions;"
query05 = "SELECT * FROM virdishc_Ironhack.00_P2_estacions_linea;"
query06 = "SELECT * FROM virdishc_Ironhack.00_P2_feed_info;"
query07 = "SELECT * FROM virdishc_Ironhack.00_P2_frequencies;"
query08 = "SELECT * FROM virdishc_Ironhack.00_P2_linies_bus;"
query09 = "SELECT * FROM virdishc_Ironhack.00_P2_parades_linia;"
query10 = "SELECT * FROM virdishc_Ironhack.00_P2_recorreguts;"
query11 = "SELECT * FROM virdishc_Ironhack.00_P2_routes;"
query12 = "SELECT * FROM virdishc_Ironhack.00_P2_stops;"
query13 = "SELECT * FROM virdishc_Ironhack.00_P2_stop_times;"
query14 = "SELECT * FROM virdishc_Ironhack.00_P2_transfers;"
query15 = "SELECT * FROM virdishc_Ironhack.00_P2_trips;"

agency = pd.read_sql(query01, engine)
calendar = pd.read_sql(query02, engine)
calendar_dates = pd.read_sql(query03, engine)
estacions = pd.read_sql(query04, engine)
estacions_linea = pd.read_sql(query05, engine)
feed_info = pd.read_sql(query06, engine)
frequencies = pd.read_sql(query07, engine)
linies_bus = pd.read_sql(query08, engine)
parades_linia = pd.read_sql(query09, engine)
recorreguts = pd.read_sql(query10, engine)
routes = pd.read_sql(query11, engine)
stops = pd.read_sql(query12, engine)
stop_times = pd.read_sql(query13, engine)
transfers = pd.read_sql(query14, engine)
trips = pd.read_sql(query15, engine)

# %% [markdown]
# Data indexes description:
# [Agency](https://developers.google.com/transit/gtfs/reference/#agencytxt "Title"), [Calendar](https://developers.google.com/transit/gtfs/reference/#calendartxt "Title"), [calendar_dates](https://developers.google.com/transit/gtfs/reference/#calendar_datestxt "Title"), [feed_info](https://developers.google.com/transit/gtfs/reference/#feed_infotxt "Title"), [frequencies](https://developers.google.com/transit/gtfs/reference/#frequenciestxt "Title"), [routes](https://developers.google.com/transit/gtfs/reference/#routestxt "Title"), [stops](https://developers.google.com/transit/gtfs/reference/#stopstxt "Title"), [stop_times](https://developers.google.com/transit/gtfs/reference/#stop_timestxt "Title"), [transfers](https://developers.google.com/transit/gtfs/reference/#transferstxt "Title"), [trips](https://developers.google.com/transit/gtfs/reference/#tripstxt "Title").

# %%
import json
import numpy as np
import math


# Data ready to create real boundaries for the stadium and Barcelona 

'''
with open('camp_nou_boundaries.txt') as json_file:  
    data_camp_nou = dict(json.load(json_file))
    new_data_camp_nou = data_camp_nou["geometries"][0]
    matrix_boundaries_camp_nou = np.array(new_data_camp_nou["coordinates"][0])
 #   print(matrix_boundaries_camp_nou)
    
with open('barcelona_boundaries.txt') as json_file:  
    data_barcelona = dict(json.load(json_file))
    new_data_barcelona = data_barcelona["geometries"][0]
    matrix_boundaries_barcelona = np.array(new_data_barcelona["coordinates"][0])
 #   print(matrix_boundaries_barcelona)    
 
''' 

''' DECLARE VARIABLES '''

internal_radius = 300
external_radius = 500
global lat_long_camp_nou
lat_long_camp_nou = (41.380898, 2.122820)
global earth_radius
earth_radius = 6378.137  # Earth_radius in kilometers

# %%
stops.dtypes
# Out:
# stop_id                 object
# stop_code              float64
# stop_name               object
# stop_lat               float64
# stop_lon               float64
# stop_url                object
# location_type            int64
# parent_station          object
# wheelchair_boarding    float64
# is_inside_perimeter       bool
# dtype: object

# %%
def is_inside_perimeter(args,lat=lat_long_camp_nou[0],lon=lat_long_camp_nou[1]):
    
    stop_lat = float(args["stop_lat"])
    stop_lon = float(args["stop_lon"])
    
    # Haversine formula https://en.wikipedia.org/wiki/Haversine_formula
    # Geographic coordinate system https://en.wikipedia.org/wiki/Geographic_coordinate_system    
    

    distance_lat = math.radians(stop_lat - lat)
    distance_lon = math.radians(stop_lon - lon)           
    lat = math.radians(lat)
    lon = math.radians(lon)
    val = math.sin(distance_lat/2)**2 + math.cos(distance_lat)*math.cos(lat)*math.sin(distance_lon/2)**2
    val = 2*math.asin(math.sqrt(val))* earth_radius * 1000
    return round(val)

# %%
# we use a disc area insted of a circle because for security laws. CROWD MANAGEMENT IN PUBLIC TRANSPORT

stops['distance_to_camp'] = stops.apply(is_inside_perimeter,axis=1)
distance = stops[(stops['distance_to_camp'] >= 400) & (stops['distance_to_camp'] <= 1000)] # stations between 400 and 1000 m from Camp Nou 
stops[]
# Out:
#             stop_id  stop_code                                      stop_name  \
# 54            1.315      315.0                                    Palau Reial
# 55            1.316      316.0                                 Maria Cristina
# 56            1.317      317.0                                      Les Corts
# 107           1.515      515.0                                      Collblanc
# 108           1.516      516.0                                          Badal
# 140           1.916      916.0                                      Collblanc
# 437   2.1361.690118     1361.0               Riera Blanca - Trav de les Corts
# 439   2.1363.675277     1363.0          Rambla del Brasil - Violant d'Hongria
# 450   2.1376.695931     1376.0                    Carles III - Maria Cristina
# 452   2.1378.675293     1378.0                   Carles III - Mejía Lequerica
# 453   2.1379.675276     1379.0                Gran Via Carles III - Av Madrid
# 669   2.1650.675305     1650.0                 Av Doctor Marañón - Av de Xile
# 709   2.1713.691613     1713.0                    Les Corts - Aurora Bertrana
# 746   2.1752.688987     1752.0                         Av Madrid - Carles III
# 747   2.1753.688989     1753.0                           Av Madrid - Benavent
# 748   2.1754.679805     1754.0                     Av Madrid - Comte de Güell
# 749   2.1755.686166     1755.0                                  Sants - Munné
# 750   2.1756.675280     1756.0                                    Metro Badal
# 757   2.1766.686067     1766.0                                    Metro Badal
# 894   2.1970.683285     1970.0                      Rambla del Brasil - Roger
# 1002    2.21.674475       21.0                                    Palau Reial
# 1204  2.2392.695656     2392.0                  Cardenal Reig - Pintor Tapiró
# 1208  2.2399.676396     2399.0                       Riera Blanca - Les Corts
# 1299  2.2530.676514     2530.0  Gran Via Carles III - Pl Reina Maria Cristina
# 1300  2.2532.689812     2532.0                         Carles III - Les Corts
# 1308  2.2542.679462     2542.0   Zona Universitària - Escola T S d'Enginyeria
# 1309  2.2543.679464     2543.0                   Diagonal - Metro Palau Reial
# 1312  2.2550.692194     2550.0                  Mini Estadi del F C Barcelona
# 1341  2.2586.677927     2586.0                      John M. Keynes - Diagonal
# 1370   2.263.689819      263.0                            Av Madrid - Arizala
# ...             ...        ...                                            ...
# 2310   2.493.683438      493.0                 Diagonal - Gran Via Carles III
# 2491   2.709.689839      709.0                         Les Corts - Carles III
# 2529   2.765.676590      765.0                                    Pl Pius XII
# 2530   2.766.674720      766.0                         Diagonal - Pl Pius XII
# 2540   2.778.693751      778.0            Av Sant Ramon Nonat - Cardenal Reig
# 2597   2.854.674680      854.0                Riera Blanca - Onze de Setembre
# 2599   2.856.675278      856.0                            Arizala - Av Madrid
# 2600   2.857.682843      857.0               Rambla del Brasil - Miquel Àngel
# 2601   2.858.689056      858.0                         Carles III - Av Madrid
# 2657   2.923.674678      923.0                    Les Corts - Mejía Lequerica
# 2886        E.31501        NaN                                 Avda. Diagonal
# 2887        E.31503        NaN                                 Avda. Diagonal
# 2888        E.31504        NaN                             Palau de Pedralbes
# 2889        E.31602        NaN                   Av. Diagonal / Doctor Ferran
# 2890        E.31603        NaN                            Gran Via Carles III
# 2891        E.31604        NaN                                  Capità Arenas
# 2892        E.31701        NaN                        Travessera de les Corts
# 2893        E.31702        NaN                                     Joan Güell
# 2999        E.51501        NaN                        Travessera de les Corts
# 3000        E.51502        NaN                           Doctor Martí i Julià
# 3001        E.51511        NaN                                     Sant Ramon
# 3002        E.51601        NaN                                Carrer de Sants
# 3003        E.51602        NaN                               Carreras i Candi
# 3004        E.51611        NaN                      Carrer de Sants / Arizala
# 3070        E.91601        NaN                                 Av. Sant Ramon
# 3141      P.6660315        NaN                                    Palau Reial
# 3142      P.6660316        NaN                                 Maria Cristina
# 3143      P.6660317        NaN                                      Les Corts
# 3186      P.6660515        NaN                                      Collblanc
# 3187      P.6660516        NaN                                          Badal
#
#        stop_lat  stop_lon stop_url  location_type parent_station  \
# 54    41.385980  2.118538     None              0      P.6660315
# 55    41.387816  2.125791     None              0      P.6660316
# 56    41.384120  2.130871     None              0      P.6660317
# 107   41.375743  2.119195     None              0      P.6660515
# 108   41.375581  2.127402     None              0      P.6660516
# 140   41.376056  2.118397     None              0      P.6660515
# 437   41.376050  2.121489     None              0           None
# 439   41.378894  2.128986     None              0           None
# 450   41.387436  2.126945     None              0           None
# 452   41.384214  2.127233     None              0           None
# 453   41.379980  2.129228     None              0           None
# 669   41.381439  2.114350     None              0           None
# 709   41.377057  2.119821     None              0           None
# 746   41.378713  2.127706     None              0           None
# 747   41.377393  2.125406     None              0           None
# 748   41.376134  2.123659     None              0           None
# 749   41.375605  2.122873     None              0           None
# 750   41.375601  2.128797     None              0           None
# 757   41.375499  2.127962     None              0           None
# 894   41.377266  2.129587     None              0           None
# 1002  41.385593  2.116137     None              0           None
# 1204  41.378542  2.117477     None              0           None
# 1208  41.377488  2.121418     None              0           None
# 1299  41.386861  2.126875     None              0           None
# 1300  41.382146  2.128466     None              0           None
# 1308  41.385077  2.115683     None              0           None
# 1309  41.385850  2.118733     None              0           None
# 1312  41.380693  2.117823     None              0           None
# 1341  41.386272  2.116581     None              0           None
# 1370  41.377042  2.125151     None              0           None
# ...         ...       ...      ...            ...            ...
# 2310  41.387589  2.125577     None              0           None
# 2491  41.382732  2.128836     None              0           None
# 2529  41.388116  2.121618     None              0           None
# 2530  41.387238  2.122615     None              0           None
# 2540  41.377434  2.116446     None              0           None
# 2597  41.377321  2.121455     None              0           None
# 2599  41.376424  2.125104     None              0           None
# 2600  41.377325  2.130095     None              0           None
# 2601  41.379788  2.128729     None              0           None
# 2657  41.381911  2.127255     None              0           None
# 2886  41.385593  2.118081     None              2      P.6660315
# 2887  41.386070  2.117721     None              2      P.6660315
# 2888  41.386128  2.117957     None              2      P.6660315
# 2889  41.388232  2.126267     None              2      P.6660316
# 2890  41.387787  2.126796     None              2      P.6660316
# 2891  41.388294  2.126507     None              2      P.6660316
# 2892  41.383898  2.130616     None              2      P.6660317
# 2893  41.384391  2.130637     None              2      P.6660317
# 2999  41.375840  2.120434     None              2      P.6660515
# 3000  41.375653  2.120625     None              2      P.6660515
# 3001  41.375806  2.118369     None              2      P.6660515
# 3002  41.375618  2.128636     None              2      P.6660516
# 3003  41.375438  2.126221     None              2      P.6660516
# 3004  41.375672  2.126032     None              2      P.6660516
# 3070  41.375869  2.118448     None              2      P.6660515
# 3141  41.385980  2.118538     None              1           None
# 3142  41.387816  2.125791     None              1           None
# 3143  41.384120  2.130871     None              1           None
# 3186  41.376056  2.118397     None              1           None
# 3187  41.375581  2.127402     None              1           None
#
#       wheelchair_boarding  is_inside_perimeter  distance_to_camp
# 54                    1.0           700.379608               700
# 55                    1.0           821.668918               822
# 56                    1.0           855.182400               855
# 107                   1.0           671.929554               672
# 108                   1.0           738.607060               739
# 140                   1.0           687.334945               687
# 437                   0.0           554.728178               555
# 439                   0.0           635.041221               635
# 450                   0.0           829.407181               829
# 452                   0.0           563.327646               563
# 453                   0.0           626.296399               626
# 669                   0.0           818.952447               819
# 709                   0.0           516.188410               516
# 746                   0.0           530.223113               530
# 747                   0.0           463.051468               463
# 748                   0.0           536.461436               536
# 749                   0.0           589.236228               589
# 750                   0.0           824.541962               825
# 757                   0.0           779.141721               779
# 894                   0.0           767.626963               768
# 1002                  0.0           829.720088               830
# 1204                  0.0           578.121637               578
# 1208                  0.0           402.954332               403
# 1299                  0.0           770.400759               770
# 1300                  0.0           561.871921               562
# 1308                  0.0           830.681402               831
# 1309                  0.0           677.637850               678
# 1312                  0.0           482.384867               482
# 1341                  0.0           848.416812               848
# 1370                  0.0           484.536648               485
# ...                   ...                  ...               ...
# 2310                  0.0           790.860448               791
# 2491                  0.0           614.980957               615
# 2529                  0.0           811.820663               812
# 2530                  0.0           706.042347               706
# 2540                  0.0           725.574867               726
# 2597                  0.0           419.380066               419
# 2599                  0.0           544.566226               545
# 2600                  0.0           806.418036               806
# 2601                  0.0           583.030300               583
# 2657                  0.0           442.270644               442
# 2886                  1.0           694.245151               694
# 2887                  2.0           757.120298               757
# 2888                  2.0           747.560870               748
# 2889                  2.0           881.484859               881
# 2890                  1.0           857.376861               857
# 2891                  2.0           896.801309               897
# 2892                  1.0           822.585207               823
# 2893                  2.0           848.152415               848
# 2999                  2.0           608.246665               608
# 3000                  2.0           621.050441               621
# 3001                  2.0           710.995961               711
# 3002                  2.0           812.395926               812
# 3003                  2.0           690.634367               691
# 3004                  1.0           659.065953               659
# 3070                  1.0           700.808718               701
# 3141                  NaN           700.379608               700
# 3142                  NaN           821.668918               822
# 3143                  NaN           855.182400               855
# 3186                  NaN           687.334945               687
# 3187                  NaN           738.607060               739
#
# [80 rows x 11 columns]

# %%
# Variables https://www.tmb.cat/ca/sobre-tmb/coneix-nos/transport-xifres
# https://www.elperiodico.com/es/barcelona/20190326/metro-informara-anden-llega-lleno-7375515    

peak_bus_number = 903
peak_metro_number = 156

Parc_mobil_bus = 1.140
Parc_mobil_metro = 171

Longitud_xarxa_metro = 121.4
Longitud_xarxa_bus = 829.68

max_capacity_metro = 959 
max_capacity_bus_18 = 143
max_capacity_bus_12 = 114

# %%
# search in databases if exisats the model of metro S9000

stops.isin(['stops']).any == '9000'
routes.isin(['routes']).any == '9000'
# Out:
# False

# %%
stops.dtypes
# Out:
# stop_id                 object
# stop_code              float64
# stop_name               object
# stop_lat               float64
# stop_lon               float64
# stop_url                object
# location_type            int64
# parent_station          object
# wheelchair_boarding    float64
# is_inside_perimeter    float64
# distance_to_camp         int64
# dtype: object

# %%
peak_bus_user_per_km = peak_bus_number / Longitud_xarxa_bus
peak_metro_user_per_km = peak_metro_number / Longitud_xarxa_metro
peak_bus_user_per_km
# Out:
# 1.0883714203066244

# %%
peak_metro_user_per_km
# Out:
# 1.28500823723229

# %%
stops.dtypes
